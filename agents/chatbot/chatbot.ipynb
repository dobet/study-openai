# %% [markdown]
# # chatbot机器人实现点关注
#
# 1. 对话模式
# 如何构建运行模式？对于消息需要如何处理？
#
# 2. 工具调用
# 如何定义工具？工具和大模型之间应该如何调用?
#
# 3. memory实现方式
# 是否支持内存？外部存储有没有？
#
# 4. 人工介入
# 哪些阶段支持介入？介入以后，是否支持修改内容？是否有可重入风险？
#
# 5. 历史会话处理
# 如何获取历史会话？
#
# 不管使用什么框架，上手的时候，都可以从这几个基本的功能点去验证实现
